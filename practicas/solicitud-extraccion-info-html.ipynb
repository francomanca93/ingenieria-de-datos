# %% [markdown]
# ## Solicitud a la web

# %%
import requests 

response = requests.get('https://www.platzi.com')

# %% [markdown]
# ### Como podemos determinar lo que hay dentro de un objeto

# %%
## Como obtener un doctring para tener información del objeto implementado
response?
# Out:
# Type:        Response
# String form: <Response [200]>
# File:        /opt/anaconda3/lib/python3.7/site-packages/requests/models.py
# Docstring:
# The :class:`Response <Response>` object, which contains a
# server's response to an HTTP request.

# %%
## Como esta implemetado la libreria dentro de python.
response??
# Out:
#         chunk_size must be of type int or None. A value of None will
#         function differently depending on the value of `stream`.
#         stream=True will read data as it arrives in whatever size the
#         chunks are received. If stream=False, data is returned as
#         a single chunk.
#
#         If decode_unicode is True, content will be decoded using the best
#         available encoding based on the response.
#         """
#
#         def generate():
#             # Special case for urllib3.
#             if hasattr(self.raw, 'stream'):
#                 try:
#                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#                         yield chunk
#                 except ProtocolError as e:
#                     raise ChunkedEncodingError(e)
#                 except DecodeError as e:
#                     raise ContentDecodingError(e)
#                 except ReadTimeoutError as e:
#                     raise ConnectionError(e)
# ...

# %%
# Obtener todos los métodos para el objeto
print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers)
# Out:
# {'Date': 'Thu, 16 Jul 2020 14:28:20 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Methods': 'GET, POST', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=86400; includeSubDomains', 'Vary': 'Accept-Encoding', 'X-Content-Type-Options': 'nosniff', 'X-DNS-Prefetch-Control': 'off', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'SAMEORIGIN', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '1; mode=block', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '03f99fc4240000f7d2680d2200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5b3c68b36f61f7d2-EZE', 'Content-Encoding': 'gzip'}

# %%
print(response.text)
# Out:
# png"},{"color":"#98ca3f","url":"/cursos/ingles-principiantes/","title":"Curso de InglÃ©s para Principiantes","badge_url":"https://static.platzi.com/media/achievements/badge-ingles-para-principiantes-54931b71-2ddd-4d61-b214-49495e5e2c40.png"},{"color":"#fd7d7a","url":"/cursos/ingles-facil-speaking/","title":"Curso de InglÃ©s PrÃ¡ctico: ConversaciÃ³n","badge_url":"https://static.platzi.com/media/achievements/badges-ingles-practico-cotidiano-09aba6ec-502d-4219-9603-5540d466f4ed.png"},{"color":"#fd7d7a","url":"/cursos/ingles-1/","title":"Curso de InglÃ©s PrÃ¡ctico: Fundamentos","badge_url":"https://static.platzi.com/media/achievements/badge-ingles-practico-fundamentos-507e913f-7aba-4017-9251-035a517c44fd.png"},{"color":"#fd7d7a","url":"/cursos/ingles-2/","title":"Curso de InglÃ©s PrÃ¡ctico: GramÃ¡tica","badge_url":"https://static.platzi.com/media/achievements/badges-ingles-practico-intermedio-754f9a30-afbc-494d-9ddd-be59e86ca7fd.png"},{"color":"#fd7d7a","url":"/cursos/ingles/","title":"C
# ...

# %% [markdown]
# ## Extracción de información del HTML

# %%
# Convirtiendo a UTF-8
response.encoding ='utf-8'

# %%
import bs4

# Generamos un parser, el cual nos permitira hacer queries al texto
soup = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.title.text)
# Out:
# 🚀Platzi: ‎Cursos Online Profesionales de Tecnología

# %%
# soup nos regresa lista de nodos
print(soup.select('meta [name=description]')[0]['content'])
# Out:
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %%
#courses_link = soup.select('.RecentCourses-item')
courses_link = soup.select('.HomeCategories-anchor')

courses = [course['href'] for course in courses_link]

for i in courses:
    print(i)
# Out:
# /categorias/desarrollo/
# /categorias/diseno/
# /categorias/marketing/
# /categorias/negocios/
# /categorias/produccion-audiovisual/
# /categorias/crecimiento-profesional/
